# %%
#hide

# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 720 kB 5.1 MB/s
#      |████████████████████████████████| 189 kB 58.7 MB/s
#      |████████████████████████████████| 48 kB 5.3 MB/s
#      |████████████████████████████████| 1.2 MB 54.2 MB/s
#      |████████████████████████████████| 55 kB 3.9 MB/s
#      |████████████████████████████████| 51 kB 257 kB/s
#      |████████████████████████████████| 558 kB 48.9 MB/s
#      |████████████████████████████████| 130 kB 52.4 MB/s
# Mounted at /content/gdrive

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # My notes from video 2022 02 22
#
# https://www.youtube.com/watch?v=BvHmRx14HQ8&t=163s
#
# ## Classification vs regression
#
# Classification - predict a category or class. From discrete options.
# Regression - predict a number, continous.
#
# ## Validateion set
#
# Val. set - not used in training so that no over-fit.
#
# ```
# learner - cnn_learner(<data>, <here name of architecture>, metrics=<list of functions that we want to run after every epoch>)
# ```
#
# error_rate = func provided by fastai to tell % of correct labels.
# accuracy func = 1.0 - error_rate.
# loss - is the measure for the algorithm to update the model to change its parameters (error_rate is for human to assess the model).
#
# ## Overfitting and training
#
# It is the key to ML - to find model that won't ofer-fit.
# Overfit - is a 'cheating' of the algorithm, so that it don't memorize data.
# Validation set is enough? No because human adjusts params to the validation set. Then use test set, 3rd set for check of human.
#
# ## How to choose sets
#
# Random selection not effective because it approximates all data.
# Instead take meaningful test and validation sets: future data or another person on photo, etc.
#
# ## Transfer learning
#
# Using another pretrained model for our model to train. That is start with that model and train our model. Example is image recognization.
#
# Why does it work? See 2013 papaer Visualizing and understanding convolutional networks re image recognization. They found how to draw neural network weights. There it is shown how images are recognized: 1 layer shows lines, 2 layer can get two lines or curvers and combines features from layer 1, 3 layer reflects patterns combining data from 1 and 2, and so on.
#
# ## Vision techniques for other fields
#
# For sound. They printed sound.
# For fraud detection on web by drawing mouse movements.
# For malicious binaries. Drawing binary.
#
# ## Questions
#
# Re catastrophic forgetting. This is when training further without giving the previous data the model forgets previous data.
#
# Re diff of model parameters and hyper (architecture) parameters (example - batch size).
#
# Where to find pretrained models? Search 'model zoo deep learning' . Like https://modelzoo.co/
#
# ## Second part
#
# ## The state of deep learning
#
# - Vision
# - Text
# - Tabular
# - Recsys (recommendation systems)
# - Multi-model: mix of prev categories (text+tab e.g.)
# - Other (protein analysis etc.)
#
# ## Interpreting model - P value
#
# Re paper re COVID-19 spread dependent on seazon, temp. Key picture there. R - how spread likely to be. Hundreds of China cities plotted.
#
# P value way to measure if hypothesis is good. Steps to get it: 1. stating a hypothesis (null hypothesis). 2. gathering data that is correlected and not correlected. 3. Calculating what percentage of times we can see this hypothesis true by chance.
#
# American stat association states that P value is bad. Because it depends on how large data set.
#
# P value doesn't work.
#
# If many axes then it does make sense?
#
# (DIDN'T UNDERSTAND)
#
# ## Null hypothesis Signification testing
#
# Univariable dependencies - not significant.
# Multivariable dependencies - more significant, more confident.
#
# ## How to turn predictive models into production ready model
#
# Drive train approach. This is approach used by Jeremy Howard, in production for many years. Instead of making constant model (e.g. prcie would be 20%) this approaches learns from environment. Basic steps are 1. setting objective; 2. defining levers that affect that objective outcome; 3. what data we collect; 4. prediction models that optimizes objective. Example is insurance co. that uses this drive train approach to set price.
#
# ## Predictical exercise with Bing Image Search

# %% [markdown]
# # Notes for lesson 3. 2022-02-24. 2022-03-10
# https://course.fast.ai/videos/?lesson=3
#
# Goes over the code in 02_production.
# Shows how to create GUI in jupyter notebook.
#
# ## How to avoid disaster
#
# Out of domain data - data that was not expected while training the model.
# Domain shift - shifting the data during the time towards unexpected place. Like detecting bears in a real life through web cam in dark.
#
# How to deal with this? Incremental:
# 1. Manual process: one expert working with the training model.
# 2. Limitted scope deployment: supervision on time and space limitted deployment.
# 3. Gradual deployment: automatic supervision.
#
# ## Unforseen consequences and feedback loops
#
# Feedback loop is the one from the police feedback loop, "predictive policing". It doesn't predict crimes but policing!
#
# ## End of ch. 2
#
# Start writing.
#
# Why blog?
# - like resume
# - helps learn
# - invitations to conferences
# - meet people
#
# https://github.com/fastai/fastpages
#
# Write to your 6 month old version of you.
#
# ## Starting MNIST
#
# Training digit classifier.
#
# Re how to untar, how to use images, how to display them as numbers. Diff between numpy `array` and `tensor` from PyTorch (GPU enhanced).
#
#
# ## Creating simple model
#
# How would I do that?
#
# His idea: pixel simularity. Take avg for every pixel and for every number. Then we can find the closest such an avg model of every number for every image and determine thus what number it is with probability better than random.
#
# L1 norm - abs dist
# L2 norm - first square then mean then squre root.
#
# tensor operates element wise and does on GPU. So can do arith operations.
#
#
# ## SGD
#
# Idea is to be able to train model. The previous method of averaging pixels is bad because it is not trainable.
#
# Stochastic Gradient Descend method:
#
# In begining weights are random.
#
# 1. Initialize weights
# 2. Given weights and an image Calculate prediction for it if is it three or seven.
# 3. For that prediction calculate the loss, i.e. how good that model is for predicting three and seven.
# 4. Based on the loss calculate the gradient that will indicate in what way weights should change to make better prediction
# 5. Change weights based on that gradient.
# 6. Repeat from step 2
# 7. Stop if we have satisfactory loss or out of time.
#
# Gradient is calculated using derivetiave.
#
# Learning rate is a ratio or coef we multiply gradient to modify our weight. It's important to pick up a good one so that we don't miss an extremum or won't learn too long.
#
# weights -= gradient(yt) * learning_rate
#
# Example in the lesson. It uses SGD to make model that predicts values for quadratic function. Quadratic func is the one we get when we measure speed of a rollarcoster that moves from one hip through another and then donw.
#
# ## MNIST loss function
#
# Similar SGD to use for our number detection. But the problem is that we need different loss and measure function because we want to avoid zeros (why?)

# %% [markdown]
# # From Model to Production

# %% [markdown]
# ## The Practice of Deep Learning

# %% [markdown]
# ### Starting Your Project

# %% [markdown]
# ### The State of Deep Learning

# %% [markdown]
# #### Computer vision

# %% [markdown]
# #### Text (natural language processing)

# %% [markdown]
# #### Combining text and images

# %% [markdown]
# #### Tabular data

# %% [markdown]
# #### Recommendation systems

# %% [markdown]
# #### Other data types

# %% [markdown]
# ### The Drivetrain Approach

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# # clean
# To download images with Bing Image Search, sign up at [Microsoft Azure](https://azure.microsoft.com/en-us/services/cognitive-services/bing-web-search-api/) for a free account. You will be given a key, which you can copy and enter in a cell as follows (replacing 'XXX' with your key and executing it):

# %%
import os
key = os.environ.get('AZURE_SEARCH_KEY', 'b87cf282aa794d248d04018ff4d7e01a')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing>

# %%
results = search_images_bing(key, 'dolphin animal')
ims = results.attrgot('contentUrl')
len(ims)
# Out:
# 150

# %%
#hide
#ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
dest = 'images/image.jpg'
download_url(ims[0], dest)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='303104' class='' max='300165' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.98% [303104/300165 00:00<00:00]
#     </div>
# Path('images/image.jpg')

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85 at 0x7F5FC0CE23D0>

# %%
bear_types = ['dolphin','shark','sperm-whale']
path = Path('animals')

# %%
if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} animal')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#437) [Path('animals/shark/00000058.jpg'),Path('animals/shark/00000125.jpg'),Path('animals/shark/00000142.jpg'),Path('animals/shark/00000099.jpg'),Path('animals/shark/00000069.jpg'),Path('animals/shark/00000071.jpg'),Path('animals/shark/00000026.jpg'),Path('animals/shark/00000108.jpg'),Path('animals/shark/00000028.jpg'),Path('animals/shark/00000078.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#4) [Path('animals/shark/00000009.jpg'),Path('animals/shark/00000127.jpg'),Path('animals/shark/00000132.jpg'),Path('animals/sperm-whale/00000129.jpg')]

# %%
failed.map(Path.unlink);

# %% [markdown]
# ### Sidebar: Getting Help in Jupyter Notebooks

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## From Data to DataLoaders

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = bears.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# ### Data Augmentation

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1051: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   ret = func(*args, **kwargs)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.698213</td>
#       <td>0.741388</td>
#       <td>0.279070</td>
#       <td>00:11</td>
#     </tr>
# ...

# %%
#uploader = widgets.FileUpload()
#uploader

# %%
#img = PILImage.create(uploader.data[0])
#learn.predict(img)

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_top_losses(2, nrows=1)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
# ...

# %%
#hide
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
dummy_input = torch.randn(1, 3, 224, 224, device='cuda')
onnx_path =  "./model.onnx"
torch.onnx.export(learn.model, dummy_input, onnx_path, verbose=False)

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/image.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('dolphin', TensorBase(0), TensorBase([9.9923e-01, 7.6991e-04, 1.5602e-06]))

# %%
learn_inf.dls.vocab
# Out:
# ['dolphin', 'shark', 'sperm-whale']

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/image.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pol
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: dolphin; Probability: 0.9992')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# ...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# ...
# Enabling: voila
# - Writing config: /usr/etc/jupyter
#     - Validating...
# Error loading server extension voila
#       X is voila importable?

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
#
# - Hand drawn picture
# - Black and white picture
# - Different colors?
#
#
# 1. Where do text models currently have a major deficiency?
#
# Correctly generating text. For example correct news, medical text, answer to post in social media, etc.
#
# 1. What are possible negative societal implications of text generation models?
#
# Disinformation, propaganda, noise generation
#
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
#
# Mixing ML processes with humans.
#
# 1. What kind of tabular data is deep learning particularly good at?
#
#
#
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
#
# It doesn't generate correct or helpful recommendations because it is not aware of the context of a user. For example what books they own now.
#
# 1. What are the steps of the Drivetrain Approach?
#
# Objective we try to optimize
# Levers we can control for the objective
# Data we can collect to monitor success
# Model we have in the end that optimizes behavior
#
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
#
# Objective is to maximize sales.
# Levers are what products to show and in what order.
# Data to collect is what products where purchased, viewed, clicked, etc.
# Model is what should be shown on some product page to increase sales.
#
# 1. Create an image recognition model using data you curate, and deploy it on the web.
#
#
# 1. What is `DataLoaders`?
#
# Wrapper around data we have to easily access validation, training sets.
#
# 1. What four things do we need to tell fastai to create `DataLoaders`?
#
# - How to get items
# - What type of date we have
# - How to categorize or label this data
# - How to get validation set from it
#
# 1. What does the `splitter` parameter to `DataBlock` do?
#
# Determines how we split into validation and training sets.
#
# 1. How do we ensure a random split always gives the same validation set?
#
# Giving the same seed.
#
# 1. What letters are often used to signify the independent and dependent variables?
#
# ImageBlock and CategoryBlock
#
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
#
# Crop - gets part of the image without resizing or scaling it.
# Pad - resizes the canvas puts image in ceter and fills the gaps.
# Squish - resizes image to fit given size.
#
# Better to randomly crop and resize to get many images from one.
#
# 1. What is data augmentation? Why is it needed?
#
# This is adding new data that is transformed, e.g. randomly resizing, cropping and color modifying an image to get many of them. We need it because data set might be small and otherwise we might get corrupted data set (e.g. padding an image with white color).
#
# 1. What is the difference between `item_tfms` and `batch_tfms`?
#
# item_tfms - a func to transform one item.
# batch_tfms - a func to transform a batch.
#
# 1. What is a confusion matrix?
#
# For each category or label it shows number of predicted items per category, i.e. categories times categories size.
#
# 1. What does `export` save?
#
# Model: architecture and parameters
#
# 1. What is it called when we use a model for getting predictions, instead of training?
#
# predict?
#
# 1. What are IPython widgets?
#
# ?
#
# 1. When might you want to use CPU for deployment? When might GPU be better?
#
# CPU for trained model in production. GPU to train a model for parallelizm.
#
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
#
# - Control is passed to the server owner.
# - Need to use network then which is unreliable sometimes.
# - Concurrent usages.
#
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
#
#
#
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?
#
# - Get a version ready for deployment.
# - Hot swap.
# - Testing it in prod

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
